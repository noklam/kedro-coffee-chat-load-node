# %%
# pip install kedro[jupyter]

# %% [markdown]
# # Using the %load_node magic to debug and prototype node quickly

# %%
# %load_ext kedro.ipython
# %load_ext autoreload
# %autoreload 2
# Or start your notebook with kedro jupyter notebook / kedro jupyter lab
# Out:
# [03/01/24 13:12:25] INFO     Registered line magic '%reload_kedro'                                   ]8;id=200514;file:///Users/Nok_Lam_Chan/dev/kedro/kedro/ipython/__init__.py\__init__.py]8;;\:]8;id=989555;file:///Users/Nok_Lam_Chan/dev/kedro/kedro/ipython/__init__.py#51\51]8;;\
#                     INFO     Registered line magic '%load_node'                                      ]8;id=180700;file:///Users/Nok_Lam_Chan/dev/kedro/kedro/ipython/__init__.py\__init__.py]8;;\:]8;id=94796;file:///Users/Nok_Lam_Chan/dev/kedro/kedro/ipython/__init__.py#53\53]8;;\
#                     INFO     Resolved project path as: /Users/Nok_Lam_Chan/dev/tmp/coffee-chat.     ]8;id=601715;file:///Users/Nok_Lam_Chan/dev/kedro/kedro/ipython/__init__.py\__init__.py]8;;\:]8;id=177900;file:///Users/Nok_Lam_Chan/dev/kedro/kedro/ipython/__init__.py#164\164]8;;\
#                              To set a different path, run '%reload_kedro <project_root>'
# [03/01/24 13:12:26] INFO     Reached after_catalog_created hook                                        ]8;id=834559;file:///Users/Nok_Lam_Chan/dev/kedro/features/steps/test_plugin/plugin.py\plugin.py]8;;\:]8;id=851060;file:///Users/Nok_Lam_Chan/dev/kedro/features/steps/test_plugin/plugin.py#15\15]8;;\
#                     INFO     Kedro project coffee-chat                                              ]8;id=716444;file:///Users/Nok_Lam_Chan/dev/kedro/kedro/ipython/__init__.py\__init__.py]8;;\:]8;id=112083;file:///Users/Nok_Lam_Chan/dev/kedro/kedro/ipython/__init__.py#134\134]8;;\
#                     INFO     Defined global variable 'context', 'session', 'catalog' and            ]8;id=318392;file:///Users/Nok_Lam_Chan/dev/kedro/kedro/ipython/__init__.py\__init__.py]8;;\:]8;id=5973;file:///Users/Nok_Lam_Chan/dev/kedro/kedro/ipython/__init__.py#135\135]8;;\
#                              'pipelines'

# %%
# %load_node
# Out:
# Docstring:
# ::
#
#   %load_node [node]
#
# The line magic %load_node <node_name>.
# Currently, this feature is only available for Jupyter Notebook (>7.0), Jupyter Lab, IPython,
# and VSCode Notebook. This line magic will generate code in multiple cells to load
# datasets from `DataCatalog`, import relevant functions and modules, node function
# definition and a function call. If generating code is not possible, it will print
# the code instead.
#
# positional arguments:
#   node  Name of the Node.
# File:      ~/dev/kedro/kedro/ipython/__init__.py

# %% [markdown]
# ### Pre-requisites
# - Requires node name (optional argument when definte a node)
# - Data need to be persisted

# %%
# %load_node create_model_input_table_node
# Out:
# [03/01/24 13:14:18] WARNING  /Users/Nok_Lam_Chan/dev/kedro/kedro/ipython/__init__.py:307:           ]8;id=747221;file:///Users/Nok_Lam_Chan/miniconda3/envs/kedro/lib/python3.10/warnings.py\warnings.py]8;;\:]8;id=230448;file:///Users/Nok_Lam_Chan/miniconda3/envs/kedro/lib/python3.10/warnings.py#109\109]8;;\
#                              UserWarning: This is an experimental feature, only Jupyter Notebook
#                              (>7.0), Jupyter Lab, IPython, and VSCode Notebook are supported. If
#                              you encounter unexpected behaviour or would like to suggest feature
#                              enhancements, add it under this github issue
#                              https://github.com/kedro-org/kedro/issues/3580
#                                warnings.warn(
# [03/01/24 13:14:21] INFO     Loading node definition from                                           ]8;id=791559;file:///Users/Nok_Lam_Chan/dev/kedro/kedro/ipython/__init__.py\__init__.py]8;;\:]8;id=286899;file:///Users/Nok_Lam_Chan/dev/kedro/kedro/ipython/__init__.py#348\348]8;;\
#                              /Users/Nok_Lam_Chan/dev/tmp/coffee-chat/src/coffee_chat/pipelines/data
#                              _processing/nodes.py

# %%
# Prepare necessary inputs for debugging
# All debugging inputs must be defined in your project catalog
shuttles = catalog.load("preprocessed_shuttles") # MemoryDataset
companies = catalog.load("preprocessed_companies")
reviews = catalog.load("reviews")
# Out:
# [03/01/24 13:14:40] INFO     Loading data from preprocessed_shuttles (ParquetDataset)...        ]8;id=275849;file:///Users/Nok_Lam_Chan/dev/kedro/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=386281;file:///Users/Nok_Lam_Chan/dev/kedro/kedro/io/data_catalog.py#483\483]8;;\
#                     INFO     Loading data from preprocessed_companies (ParquetDataset)...       ]8;id=23120;file:///Users/Nok_Lam_Chan/dev/kedro/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=396780;file:///Users/Nok_Lam_Chan/dev/kedro/kedro/io/data_catalog.py#483\483]8;;\
#                     INFO     Loading data from reviews (CSVDataset)...                          ]8;id=236807;file:///Users/Nok_Lam_Chan/dev/kedro/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=474036;file:///Users/Nok_Lam_Chan/dev/kedro/kedro/io/data_catalog.py#483\483]8;;\

# %%
import pandas as pd

# %%
rated_shuttles = shuttles.merge(reviews, left_on="id", right_on="shuttle_id")
print(rated_shuttles.head())
rated_shuttles = rated_shuttles.drop("id", axis=1)
# Out:
#       id       shuttle_location shuttle_type engine_type       engine_vendor  \
# 0  45163  Sao Tome and Principe      Type V5      Plasma  ThetaBase Services
# 1  49438      Wallis and Futuna      Type V2      Plasma  ThetaBase Services
# 2  10750                   Niue      Type F5     Quantum  ThetaBase Services
# 3   4146                  Malta      Type V2     Quantum  ThetaBase Services
# 4   5067                  Malta      Type V2      Plasma  ThetaBase Services
#
#    engines  passenger_capacity cancellation_policy  crew  d_check_complete  \
# 0      2.0                   4            moderate   2.0             False
# 1      3.0                   5            moderate   3.0             False
# 2      1.0                   2              strict   1.0              True
# 3      1.0                   2            moderate   1.0             False
# 4      5.0                  10              strict   5.0             False
#
#    ...  shuttle_id  review_scores_rating  review_scores_comfort  \
# 0  ...       45163                  91.0                   10.0
# 1  ...       49438                  96.0                   10.0
# 2  ...       10750                  97.0                   10.0
# 3  ...        4146                  95.0                   10.0
# 4  ...        5067                  97.0                   10.0
#
#    review_scores_amenities  review_scores_trip  review_scores_crew  \
# 0                      9.0                 9.0                 9.0
# 1                     10.0                10.0                10.0
# 2                     10.0                10.0                10.0
# 3                     10.0                10.0                10.0
# 4                      9.0                10.0                10.0
#
#    review_scores_location  review_scores_price  number_of_reviews  \
# 0                     9.0                  9.0                 26
# 1                    10.0                  9.0                 61
# 2                    10.0                 10.0                467
# 3                     9.0                  9.0                318
# 4                     9.0                 10.0                 22
#
#    reviews_per_month
# 0               0.77
# 1               0.62
# 2               4.66
# 3               3.22
# 4               0.29
#
# [5 rows x 23 columns]

# %%
rated_shuttles.head().T
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#       <th>1</th>
#       <th>2</th>
#       <th>3</th>
#       <th>4</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>shuttle_location</th>
#       <td>Sao Tome and Principe</td>
#       <td>Wallis and Futuna</td>
#       <td>Niue</td>
#       <td>Malta</td>
#       <td>Malta</td>
#     </tr>
#     <tr>
#       <th>shuttle_type</th>
#       <td>Type V5</td>
#       <td>Type V2</td>
#       <td>Type F5</td>
#       <td>Type V2</td>
#       <td>Type V2</td>
#     </tr>
#     <tr>
#       <th>engine_type</th>
#       <td>Plasma</td>
#       <td>Plasma</td>
#       <td>Quantum</td>
#       <td>Quantum</td>
#       <td>Plasma</td>
#     </tr>
#     <tr>
#       <th>engine_vendor</th>
#       <td>ThetaBase Services</td>
#       <td>ThetaBase Services</td>
#       <td>ThetaBase Services</td>
#       <td>ThetaBase Services</td>
#       <td>ThetaBase Services</td>
#     </tr>
#     <tr>
#       <th>engines</th>
#       <td>2.0</td>
#       <td>3.0</td>
#       <td>1.0</td>
#       <td>1.0</td>
#       <td>5.0</td>
#     </tr>
#     <tr>
#       <th>passenger_capacity</th>
#       <td>4</td>
#       <td>5</td>
#       <td>2</td>
#       <td>2</td>
#       <td>10</td>
#     </tr>
#     <tr>
#       <th>cancellation_policy</th>
#       <td>moderate</td>
#       <td>moderate</td>
#       <td>strict</td>
#       <td>moderate</td>
#       <td>strict</td>
#     </tr>
#     <tr>
#       <th>crew</th>
#       <td>2.0</td>
#       <td>3.0</td>
#       <td>1.0</td>
#       <td>1.0</td>
#       <td>5.0</td>
#     </tr>
#     <tr>
#       <th>d_check_complete</th>
#       <td>False</td>
#       <td>False</td>
#       <td>True</td>
#       <td>False</td>
#       <td>False</td>
#     </tr>
#     <tr>
#       <th>moon_clearance_complete</th>
#       <td>False</td>
#       <td>False</td>
#       <td>False</td>
#       <td>False</td>
#       <td>False</td>
#     </tr>
#     <tr>
#       <th>price</th>
#       <td>1715.0</td>
#       <td>3405.0</td>
#       <td>1806.0</td>
#       <td>1676.0</td>
#       <td>4718.0</td>
#     </tr>
#     <tr>
#       <th>company_id</th>
#       <td>32413</td>
#       <td>14122</td>
#       <td>47761</td>
#       <td>26648</td>
#       <td>26648</td>
#     </tr>
#     <tr>
#       <th>shuttle_id</th>
#       <td>45163</td>
#       <td>49438</td>
#       <td>10750</td>
#       <td>4146</td>
#       <td>5067</td>
#     </tr>
#     <tr>
#       <th>review_scores_rating</th>
#       <td>91.0</td>
#       <td>96.0</td>
#       <td>97.0</td>
#       <td>95.0</td>
#       <td>97.0</td>
#     </tr>
#     <tr>
#       <th>review_scores_comfort</th>
#       <td>10.0</td>
#       <td>10.0</td>
#       <td>10.0</td>
#       <td>10.0</td>
#       <td>10.0</td>
#     </tr>
#     <tr>
#       <th>review_scores_amenities</th>
#       <td>9.0</td>
#       <td>10.0</td>
#       <td>10.0</td>
#       <td>10.0</td>
#       <td>9.0</td>
#     </tr>
#     <tr>
#       <th>review_scores_trip</th>
#       <td>9.0</td>
#       <td>10.0</td>
#       <td>10.0</td>
#       <td>10.0</td>
#       <td>10.0</td>
#     </tr>
#     <tr>
#       <th>review_scores_crew</th>
#       <td>9.0</td>
#       <td>10.0</td>
#       <td>10.0</td>
#       <td>10.0</td>
#       <td>10.0</td>
#     </tr>
#     <tr>
#       <th>review_scores_location</th>
#       <td>9.0</td>
#       <td>10.0</td>
#       <td>10.0</td>
#       <td>9.0</td>
#       <td>9.0</td>
#     </tr>
#     <tr>
#       <th>review_scores_price</th>
#       <td>9.0</td>
#       <td>9.0</td>
#       <td>10.0</td>
#       <td>9.0</td>
#       <td>10.0</td>
#     </tr>
#     <tr>
#       <th>number_of_reviews</th>
#       <td>26</td>
#       <td>61</td>
#       <td>467</td>
#       <td>318</td>
#       <td>22</td>
#     </tr>
#     <tr>
#       <th>reviews_per_month</th>
#       <td>0.77</td>
#       <td>0.62</td>
#       <td>4.66</td>
#       <td>3.22</td>
#       <td>0.29</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
companies.head().T
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#       <th>1</th>
#       <th>2</th>
#       <th>3</th>
#       <th>4</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>id</th>
#       <td>3888</td>
#       <td>46728</td>
#       <td>34618</td>
#       <td>28619</td>
#       <td>8240</td>
#     </tr>
#     <tr>
#       <th>company_rating</th>
#       <td>1.0</td>
#       <td>1.0</td>
#       <td>0.38</td>
#       <td>1.0</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>company_location</th>
#       <td>Isle of Man</td>
#       <td>None</td>
#       <td>Isle of Man</td>
#       <td>Bosnia and Herzegovina</td>
#       <td>Chile</td>
#     </tr>
#     <tr>
#       <th>total_fleet_count</th>
#       <td>1.0</td>
#       <td>1.0</td>
#       <td>1.0</td>
#       <td>1.0</td>
#       <td>1.0</td>
#     </tr>
#     <tr>
#       <th>iata_approved</th>
#       <td>False</td>
#       <td>False</td>
#       <td>False</td>
#       <td>False</td>
#       <td>True</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
model_input_table = rated_shuttles.merge(
    companies, left_on="company_id", right_on="id"
)
model_input_table = model_input_table.dropna()
    # return model_input_table

# %%
model_input_table.head().T
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#       <th>1</th>
#       <th>2</th>
#       <th>3</th>
#       <th>4</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>shuttle_location</th>
#       <td>Sao Tome and Principe</td>
#       <td>Wallis and Futuna</td>
#       <td>Niue</td>
#       <td>Malta</td>
#       <td>Malta</td>
#     </tr>
#     <tr>
#       <th>shuttle_type</th>
#       <td>Type V5</td>
#       <td>Type V2</td>
#       <td>Type F5</td>
#       <td>Type V2</td>
#       <td>Type V2</td>
#     </tr>
#     <tr>
#       <th>engine_type</th>
#       <td>Plasma</td>
#       <td>Plasma</td>
#       <td>Quantum</td>
#       <td>Quantum</td>
#       <td>Plasma</td>
#     </tr>
#     <tr>
#       <th>engine_vendor</th>
#       <td>ThetaBase Services</td>
#       <td>ThetaBase Services</td>
#       <td>ThetaBase Services</td>
#       <td>ThetaBase Services</td>
#       <td>ThetaBase Services</td>
#     </tr>
#     <tr>
#       <th>engines</th>
#       <td>2.0</td>
#       <td>3.0</td>
#       <td>1.0</td>
#       <td>1.0</td>
#       <td>5.0</td>
#     </tr>
#     <tr>
#       <th>passenger_capacity</th>
#       <td>4</td>
#       <td>5</td>
#       <td>2</td>
#       <td>2</td>
#       <td>10</td>
#     </tr>
#     <tr>
#       <th>cancellation_policy</th>
#       <td>moderate</td>
#       <td>moderate</td>
#       <td>strict</td>
#       <td>moderate</td>
#       <td>strict</td>
#     </tr>
#     <tr>
#       <th>crew</th>
#       <td>2.0</td>
#       <td>3.0</td>
#       <td>1.0</td>
#       <td>1.0</td>
#       <td>5.0</td>
#     </tr>
#     <tr>
#       <th>d_check_complete</th>
#       <td>False</td>
#       <td>False</td>
#       <td>True</td>
#       <td>False</td>
#       <td>False</td>
#     </tr>
#     <tr>
#       <th>moon_clearance_complete</th>
#       <td>False</td>
#       <td>False</td>
#       <td>False</td>
#       <td>False</td>
#       <td>False</td>
#     </tr>
#     <tr>
#       <th>price</th>
#       <td>1715.0</td>
#       <td>3405.0</td>
#       <td>1806.0</td>
#       <td>1676.0</td>
#       <td>4718.0</td>
#     </tr>
#     <tr>
#       <th>company_id</th>
#       <td>32413</td>
#       <td>14122</td>
#       <td>47761</td>
#       <td>26648</td>
#       <td>26648</td>
#     </tr>
#     <tr>
#       <th>shuttle_id</th>
#       <td>45163</td>
#       <td>49438</td>
#       <td>10750</td>
#       <td>4146</td>
#       <td>5067</td>
#     </tr>
#     <tr>
#       <th>review_scores_rating</th>
#       <td>91.0</td>
#       <td>96.0</td>
#       <td>97.0</td>
#       <td>95.0</td>
#       <td>97.0</td>
#     </tr>
#     <tr>
#       <th>review_scores_comfort</th>
#       <td>10.0</td>
#       <td>10.0</td>
#       <td>10.0</td>
#       <td>10.0</td>
#       <td>10.0</td>
#     </tr>
#     <tr>
#       <th>review_scores_amenities</th>
#       <td>9.0</td>
#       <td>10.0</td>
#       <td>10.0</td>
#       <td>10.0</td>
#       <td>9.0</td>
#     </tr>
#     <tr>
#       <th>review_scores_trip</th>
#       <td>9.0</td>
#       <td>10.0</td>
#       <td>10.0</td>
#       <td>10.0</td>
#       <td>10.0</td>
#     </tr>
#     <tr>
#       <th>review_scores_crew</th>
#       <td>9.0</td>
#       <td>10.0</td>
#       <td>10.0</td>
#       <td>10.0</td>
#       <td>10.0</td>
#     </tr>
#     <tr>
#       <th>review_scores_location</th>
#       <td>9.0</td>
#       <td>10.0</td>
#       <td>10.0</td>
#       <td>9.0</td>
#       <td>9.0</td>
#     </tr>
#     <tr>
#       <th>review_scores_price</th>
#       <td>9.0</td>
#       <td>9.0</td>
#       <td>10.0</td>
#       <td>9.0</td>
#       <td>10.0</td>
#     </tr>
#     <tr>
#       <th>number_of_reviews</th>
#       <td>26</td>
#       <td>61</td>
#       <td>467</td>
#       <td>318</td>
#       <td>22</td>
#     </tr>
#     <tr>
#       <th>reviews_per_month</th>
#       <td>0.77</td>
#       <td>0.62</td>
#       <td>4.66</td>
#       <td>3.22</td>
#       <td>0.29</td>
#     </tr>
#     <tr>
#       <th>id</th>
#       <td>32413</td>
#       <td>14122</td>
#       <td>47761</td>
#       <td>26648</td>
#       <td>26648</td>
#     </tr>
#     <tr>
#       <th>company_rating</th>
#       <td>1.0</td>
#       <td>1.0</td>
#       <td>1.0</td>
#       <td>1.0</td>
#       <td>1.0</td>
#     </tr>
#     <tr>
#       <th>company_location</th>
#       <td>Faroe Islands</td>
#       <td>Malta</td>
#       <td>Niue</td>
#       <td>Niue</td>
#       <td>Niue</td>
#     </tr>
#     <tr>
#       <th>total_fleet_count</th>
#       <td>1.0</td>
#       <td>1.0</td>
#       <td>2.0</td>
#       <td>2.0</td>
#       <td>2.0</td>
#     </tr>
#     <tr>
#       <th>iata_approved</th>
#       <td>False</td>
#       <td>True</td>
#       <td>False</td>
#       <td>True</td>
#       <td>True</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
create_model_input_table(shuttles, companies, reviews)
# Out:
#       id       shuttle_location shuttle_type engine_type       engine_vendor  \
# 0  45163  Sao Tome and Principe      Type V5      Plasma  ThetaBase Services
# 1  49438      Wallis and Futuna      Type V2      Plasma  ThetaBase Services
# 2  10750                   Niue      Type F5     Quantum  ThetaBase Services
# 3   4146                  Malta      Type V2     Quantum  ThetaBase Services
# 4   5067                  Malta      Type V2      Plasma  ThetaBase Services
#
#    engines  passenger_capacity cancellation_policy  crew  d_check_complete  \
# 0      2.0                   4            moderate   2.0             False
# 1      3.0                   5            moderate   3.0             False
# 2      1.0                   2              strict   1.0              True
# 3      1.0                   2            moderate   1.0             False
# 4      5.0                  10              strict   5.0             False
#
#    ...  shuttle_id  review_scores_rating  review_scores_comfort  \
# 0  ...       45163                  91.0                   10.0
# 1  ...       49438                  96.0                   10.0
# 2  ...       10750                  97.0                   10.0
# 3  ...        4146                  95.0                   10.0
# 4  ...        5067                  97.0                   10.0
#
#    review_scores_amenities  review_scores_trip  review_scores_crew  \
# 0                      9.0                 9.0                 9.0
# 1                     10.0                10.0                10.0
# 2                     10.0                10.0                10.0
# 3                     10.0                10.0                10.0
# 4                      9.0                10.0                10.0
#
#    review_scores_location  review_scores_price  number_of_reviews  \
# 0                     9.0                  9.0                 26
# 1                    10.0                  9.0                 61
# 2                    10.0                 10.0                467
# 3                     9.0                  9.0                318
# 4                     9.0                 10.0                 22
#
#    reviews_per_month
# 0               0.77
# 1               0.62
# 2               4.66
# 3               3.22
# 4               0.29
#
# [5 rows x 23 columns]
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ /var/folders/qq/wpp9vnws3sqcv6v3td68qcpm0000gp/T/ipykernel_43436/3761210180.py:1 in <module>     │
# │                                                                                                  │
# │ [Errno 2] No such file or directory:                                                             │
# │ '/var/folders/qq/wpp9vnws3sqcv6v3td68qcpm0000gp/T/ipykernel_43436/3761210180.py'                 │
# │                                                                                                  │
# │ /var/folders/qq/wpp9vnws3sqcv6v3td68qcpm0000gp/T/ipykernel_43436/3570333138.py:17 in             │
# │ create_model_input_table                                                                         │
# │                                                                                                  │
# │ [Errno 2] No such file or directory:                                                             │
# │ '/var/folders/qq/wpp9vnws3sqcv6v3td68qcpm0000gp/T/ipykernel_43436/3570333138.py'                 │
# │                                                                                                  │
# │ /Users/Nok_Lam_Chan/miniconda3/envs/kedro/lib/python3.10/site-packages/pandas/core/frame.py:1080 │
# │ 5 in merge                                                                                       │
# │                                                                                                  │
# │   10802 │   ) -> DataFrame:                                                                      │
# │   10803 │   │   from pandas.core.reshape.merge import merge                                      │
# │   10804 │   │                                                                                    │
# │ ❱ 10805 │   │   return merge(                                                                    │
# │   10806 │   │   │   self,                                                                        │
# │   10807 │   │   │   right,                                                                       │
# │   10808 │   │   │   how=how,                                                                     │
# │                                                                                                  │
# │ /Users/Nok_Lam_Chan/miniconda3/envs/kedro/lib/python3.10/site-packages/pandas/core/reshape/merge │
# │ .py:170 in merge                                                                                 │
# │                                                                                                  │
# │    167 │   │   │   copy=copy,                                                                    │
# │    168 │   │   )                                                                                 │
# │    169 │   else:                                                                                 │
# │ ❱  170 │   │   op = _MergeOperation(                                                             │
# │    171 │   │   │   left_df,                                                                      │
# │    172 │   │   │   right_df,                                                                     │
# │    173 │   │   │   how=how,                                                                      │
# │                                                                                                  │
# │ /Users/Nok_Lam_Chan/miniconda3/envs/kedro/lib/python3.10/site-packages/pandas/core/reshape/merge │
# │ .py:794 in __init__                                                                              │
# │                                                                                                  │
# │    791 │   │   │   self.join_names,                                                              │
# │    792 │   │   │   left_drop,                                                                    │
# │    793 │   │   │   right_drop,                                                                   │
# │ ❱  794 │   │   ) = self._get_merge_keys()                                                        │
# │    795 │   │                                                                                     │
# │    796 │   │   if left_drop:                                                                     │
# │    797 │   │   │   self.left = self.left._drop_labels_or_levels(left_drop)                       │
# │                                                                                                  │
# │ /Users/Nok_Lam_Chan/miniconda3/envs/kedro/lib/python3.10/site-packages/pandas/core/reshape/merge │
# │ .py:1297 in _get_merge_keys                                                                      │
# │                                                                                                  │
# │   1294 │   │   │   │   │   │   #  the latter of which will raise                                 │
# │   1295 │   │   │   │   │   │   rk = cast(Hashable, rk)                                           │
# │   1296 │   │   │   │   │   │   if rk is not None:                                                │
# │ ❱ 1297 │   │   │   │   │   │   │   right_keys.append(right._get_label_or_level_values(rk))       │
# │   1298 │   │   │   │   │   │   else:                                                             │
# │   1299 │   │   │   │   │   │   │   # work-around for merge_asof(right_index=True)                │
# │   1300 │   │   │   │   │   │   │   right_keys.append(right.index._values)                        │
# │                                                                                                  │
# │ /Users/Nok_Lam_Chan/miniconda3/envs/kedro/lib/python3.10/site-packages/pandas/core/generic.py:19 │
# │ 10 in _get_label_or_level_values                                                                 │
# │                                                                                                  │
# │    1907 │   │   elif self._is_level_reference(key, axis=axis):                                   │
# │    1908 │   │   │   values = self.axes[axis].get_level_values(key)._values                       │
# │    1909 │   │   else:                                                                            │
# │ ❱  1910 │   │   │   raise KeyError(key)                                                          │
# │    1911 │   │                                                                                    │
# │    1912 │   │   # Check for duplicates                                                           │
# │    1913 │   │   if values.ndim > 1:                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯
# KeyError: 'company_id'

# %% [markdown]
# # Debug Effectively
# - Debug function, not pipeline
# - Narrow your scope (log, checkpoint), think about unit tests! Countless hour waiting for `kedro run` during support calls.
# - Read the logs (tips: you can click the log and jump into the definition)
# - See if you can go beyond `kedro run` or `kedro run --pipeline <pipeline>` (explore the options! [kedro-viz](demo.kedro.org) can help)

# %% [markdown]
# ```
# INFO     Running node: create_model_input_table_node:                                 node.py:340
#             create_model_input_table([preprocessed_shuttles;preprocessed_companies;revie
#             ws]) -> [model_input_table]
# ERROR    Node create_model_input_table_node: create_model_input_table() ->  failed    node.py:365
#             with error:
#             'company_id'
# WARNING  There are 4 nodes that have not run.                                       runner.py:218
#             You can resume the pipeline run from the nearest nodes with persisted
#             inputs by adding the following argument to your previous command:
#             --from-nodes "create_model_input_table_node"
# ```
